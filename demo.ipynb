# %%
# !pip install opencv-python
import cv2
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from gensim.models import word2vec
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %%
df = pd.read_csv("colors.csv")

# %%
df.head()
# Out:
#            color1       color2         color3         color4         color5
# 0             tan        black  darkslategray      gainsboro           gray
# 1          sienna          tan          black    saddlebrown      rosybrown
# 2          silver        black            tan  darkslategray           gray
# 3  darkolivegreen          tan          black           gray  darkslategray
# 4             tan  saddlebrown          black          coral         maroon

# %%
X = df.iloc[:,:].values

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder =  OrdinalEncoder()
X = encoder.fit_transform(X)
# Y =  pd.df(X)

# %%
X
# Out:
# array([[14.,  0.,  6., 10.,  8.],
#        [12., 12.,  1., 19., 14.],
#        [13.,  0., 22.,  8.,  8.],
#        [ 2., 12.,  1., 11.,  5.],
#        [14.,  9.,  1.,  3., 12.],
#        [14.,  0., 18., 20., 21.],
#        [14.,  3.,  9.,  1.,  6.],
#        [14., 10., 16., 19., 16.],
#        [14.,  9., 16.,  1., 15.],
#        [ 4., 12.,  2., 12., 13.],
#        [14.,  3., 20.,  9., 14.],
#        [ 0., 10., 15., 17., 19.],
#        [ 1., 12.,  9., 21.,  3.],
#        [14.,  3.,  1., 21., 11.],
#        [ 4., 12.,  5., 10.,  8.],
#        [12., 12.,  6., 19., 13.],
#        [ 4., 12., 10., 22., 10.],
#        [14.,  0., 19., 12.,  1.],
#        [ 4., 12.,  8., 11., 18.],
#        [14.,  8.,  1., 10.,  6.],
#        [ 6.,  0.,  5.,  0., 19.],
#        [14.,  0.,  7.,  8., 14.],
#        [14.,  0.,  9.,  9., 14.],
#        [14.,  2.,  6.,  2.,  7.],
#        [ 1., 12.,  5.,  8.,  8.],
#        [ 1., 12.,  4., 19., 17.],
#        [14.,  7.,  4., 20.,  1.],
#        [14., 10.,  1., 11.,  0.],
#        [ 7.,  3., 22.,  1.,  8.],
#        [14.,  0., 20.,  7.,  3.],
#        [14.,  7., 19., 19.,  1.],
#        [14.,  0., 14., 11.,  5.],
#        [14.,  3., 16.,  1., 15.],
#        [ 1., 12., 21., 20.,  5.],
#        [14., 13.,  5., 11.,  9.],
#        [10., 12., 19., 16.,  1.],
#        [ 6.,  3., 22.,  1.,  6.],
#        [14.,  0.,  7.,  8.,  2.],
#        [14.,  4.,  9.,  8., 14.],
#        [14.,  0., 20., 18.,  5.],
#        [ 9., 12.,  1.,  9.,  7.],
#        [14.,  3.,  7.,  5., 18.],
#        [14.,  3.,  9.,  1.,  7.],
#        [14.,  3.,  9., 14.,  6.],
#        [ 1., 12., 20., 10., 14.],
#        [14.,  0., 20.,  6.,  4.],
#        [14.,  3.,  7., 18.,  1.],
#        [14.,  0., 17., 11., 20.],
#        [14.,  2.,  5., 18.,  5.],
#        [14.,  3., 11., 17., 17.],
#        [14.,  0., 18., 11.,  2.],
#        [14.,  4.,  6., 13.,  8.],
#        [15., 10., 22.,  8., 14.],
#        [14., 10., 19., 11.,  1.],
#        [10., 12.,  6.,  6.,  1.],
#        [ 7.,  1., 22.,  9.,  8.],
#        [11., 12., 16., 19.,  4.],
#        [ 1., 12., 18., 15.,  3.],
#        [ 8.,  3.,  6., 11., 19.],
#        [14.,  0.,  9.,  6., 14.],
#        [14., 10., 18., 13.,  1.],
#        [14.,  4.,  8.,  1., 14.],
#        [14.,  0.,  7., 18.,  5.],
#        [ 1., 12.,  7.,  8.,  8.],
#        [14.,  0.,  7.,  8.,  8.],
#        [14.,  0.,  9.,  9.,  5.],
#        [14.,  4., 12.,  8.,  2.],
#        [14., 10., 16., 19.,  5.],
#        [ 3.,  6., 10.,  8., 19.],
#        [ 5., 12.,  1., 18.,  5.],
#        [14., 11., 19., 12.,  1.],
#        [14.,  0.,  5.,  9.,  1.],
#        [14.,  0.,  3.,  9.,  5.],
#        [14.,  0.,  8.,  6., 14.],
#        [14.,  0., 19., 17.,  9.],
#        [14.,  0., 19., 11.,  5.],
#        [14.,  0.,  0., 18.,  5.],
#        [ 5., 12.,  1.,  6., 14.],
#        [14.,  3.,  9.,  1.,  7.],
#        [14.,  3.,  9., 10.,  3.],
#        [ 5., 12.,  6.,  6.,  1.],
#        [14.,  3., 16., 14., 18.],
#        [ 3., 12.,  1., 19., 17.],
#        [ 5., 12., 13.,  8., 14.],
#        [14.,  5., 10.,  4., 12.],
#        [ 1., 12.,  7., 11., 11.],
#        [14.,  3., 13., 20.,  9.],
#        [14.,  4.,  8.,  8.,  2.],
#        [ 1., 12.,  7.,  6., 14.]])

# %%
# df.to_csv('yoyo.csv', index = None)

# %%
training_data = df.sample(frac=0.8, random_state=25)
testing_data = df.drop(training_data.index)

print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")
# Out:
# No. of training examples: 71
# No. of testing examples: 18

# %%
import cv2
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
# from gensim.models import word2vec
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("colors.csv")

# %%
from csv import reader
with open('colors.csv', 'r') as f:
    csv_reader = reader(f)
    final = []
    index = []
    # given = ['tan','darkslategray','black','lightslategray','indianred']
    # given = ['tan','darkolivegreen','black','rosybrown','dimgray']
    # given = ['tan','saddlebrown','peru','darksalmon','saddlebrown']
    # given = ['indianred','tan','darkslategray','darkslategray','lavender']
    count = 0


    for row in csv_reader:
        found = 0
        for j in row:
            if(j!='color1' and j!='color2' and j!='color3' and j!='color4' and j!='color5'):
                for i in given:
                    if(i==j):
                        found+=1
                        break
        if(found>=3):
            index.append(count)
        count+=1

# %%
print(index)
final = index[0:10]
# Out:
# [2, 4, 6, 7, 11, 13, 18, 20, 21, 22, 23, 25, 30, 37, 38, 39, 40, 41, 45, 46, 47, 49, 51, 55, 56, 58, 60, 61, 62, 63, 64, 65, 66, 70, 72, 73, 74, 77, 78, 81, 84, 86, 89]

# %%
print(final)
# Out:
# [8, 9, 16, 31, 33, 36, 57, 68, 75, 83]

# %%
from PIL import Image
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

for i in final:
    # im = Image.open(('new_img{n}.jpg').format(n=i))
    # im.show()
    # plt.imshow(('new_img{n}.jpg').format(n=i))

    img = mpimg.imread(('new_img{n}.jpg').format(n=i))
    imgplot = plt.imshow(img)
    plt.axis("off")
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
